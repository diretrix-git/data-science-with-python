# %%
import pandas as pd
import numpy as np

# %%
csv_filename = "pandas_dataset.csv"

df = pd.read_csv(csv_filename, header = 2)

initial_shape = df.shape

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

df = df.reset_index(drop=True)

df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 csv_filename = "pandas_dataset.csv"
#       2
# ----> 3 df = pd.read_csv(csv_filename, header = 2)
#       4
#       5 initial_shape = df.shape
#       6
#
# NameError: name 'pd' is not defined
